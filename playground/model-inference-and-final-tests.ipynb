# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("WebOrganizer/TopicClassifier-NoURL")
model = AutoModelForSequenceClassification.from_pretrained(
    "WebOrganizer/TopicClassifier-NoURL",
    trust_remote_code=True,
    use_memory_efficient_attention=False)

web_page = """Models Datasets Spaces Posts Docs Enterprise Pricing Log In Sign Up
WebOrganizer/TopicClassifier-NoURL Usage Citation
Usage Citation


[ Paper ] [ Website ] [ GitHub ]
The TopicClassifier-NoURL organizes web content into 17 categories based on the text contents of web pages (without using URL information).
The model is a gte-base-en-v1.5 with 140M parameters fine-tuned on the following training data:
WebOrganizer/TopicAnnotations-Llama-3.1-8B : 1M documents annotated by Llama-3.1-8B (first-stage training) WebOrganizer/TopicAnnotations-Llama-3.1-405B-FP8 : 100K documents annotated by Llama-3.1-405B-FP8 (second-stage training)
WebOrganizer/FormatClassifier WebOrganizer/FormatClassifier-NoURL WebOrganizer/TopicClassifier WebOrganizer/TopicClassifier-NoURL ← you are here!
This classifier expects input in the following format:
Example:
You can convert the logits of the model with a softmax to obtain a probability distribution over the following 24 categories (in order of labels, also see id2label and label2id in the model config):
Adult Art & Design Software Dev. Crime & Law Education & Jobs Hardware Entertainment Social Life Fashion & Beauty Finance & Business Food & Dining Games Health History Home & Hobbies Industrial Literature Politics Religion Science & Tech. Software Sports & Fitness Transportation Travel
The full definitions of the categories can be found in the taxonomy config .
We recommend that you use the efficient gte-base-en-v1.5 implementation by enabling unpadding and memory efficient attention. This requires installing xformers (see more here ) and loading the model like:
Files info
Base model
"""

inputs = tokenizer([web_page], return_tensors="pt")
outputs = model(**inputs)
print(outputs)
print()

probs = outputs.logits.softmax(dim=-1)
print(probs.argmax(dim=-1).item())

pred_index = probs.argmax(dim=-1).item()
confidence_score = probs[0, pred_index]
print(confidence_score.item())
print()

id2label = model.config.id2label
pred_label = id2label[pred_index]
print()
print(pred_label)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.68k [00:00<?, ?B/s]
# configuration.py:   0%|          | 0.00/7.13k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/WebOrganizer/TopicClassifier-NoURL:
# - configuration.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling.py:   0%|          | 0.00/59.0k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/WebOrganizer/TopicClassifier-NoURL:
# - modeling.py
# ...

# %% [markdown]
# # Gradio
# Gradio spaces in huggingface will be used to host the model for free, the function will take the scraped content as input and output will be label i.e {'prediction': 'label', 'confidence': confidence}

# %% [markdown]
# ### Model on Gradio
# Now that the model is on gradio let's test its endpoint

# %%
# !pip install -q gradio_client
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.1/323.1 kB 6.3 MB/s eta 0:00:00:00:01

# %%
# !git clone https://github.com/angeltamang123/URL-Content-Categorizer
# Out:
# Cloning into 'URL-Content-Categorizer'...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 75 (delta 30), reused 57 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (75/75), 342.71 KiB | 4.03 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# !pip install -q cloudscraper pytest-playwright
# !playwright install --with-deps
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 MB 33.5 MB/s eta 0:00:00:00:0100:01
# Installing dependencies...
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,676 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,723 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# ...

# %%
# cd URL-Content-Categorizer in terminal before this cell

from utils.scraper import Scrape_URL
from gradio_client import Client

url = "https://www.notion.com/"
scraper = Scrape_URL(url=url)
x, y, content = await scraper.scrape()

space_id = "Vyke2000/WebOrganizer-TopicClassifier-NoURL_on_Gradio_Spaces"
client = Client(space_id)

result = client.predict(content, api_name="/predict")
print(f"The topic is categorized as {result['topic']} with the model being {result['confidence'] * 100}% confident ")
# Out:
# Requests scrape job starting....
# Requests scrape job completed with 345 words worth of content
# Loaded as API: https://vyke2000-weborganizer-topicclassifier-nourl-on-g-4e2831b.hf.space ✔
# The topic is categorized as Software with the model being 93.28% confident

# %% [markdown]
# ### Model on Gradio
# The model is on gradio and working as intended, now we write script that automates scraping and inference

# %%
# !pwd
# Out:
# /kaggle/working/URL-Content-Categorizer

# %%
# !python categorize.py --url https://www.hulu.com/welcome
# Out:
# Requests scrape job starting....
# Requests scrape job completed with 147 words worth of content
# Using the scraping output of requests with word count of 147
# as input to the model
# Loaded as API: https://vyke2000-weborganizer-topicclassifier-nourl-on-g-4e2831b.hf.space ✔
# The topic is categorized as Entertainment with the model being 92.12% confident

# %% [markdown]
# *Now let's check what happens when gradio service is private*

# %%
# !python categorize.py --url https://www.trip.com/travel-guide
# Out:
# Requests scrape job starting....
# Requests scrape job completed with 69 words worth of content
# Playwright scrape job starting....
# Page loaded.
# Playwright working: 60/60s                    Playwright scrape job completed with 46 words worth of content
# Using the scraping output of requests with word count of 46
# as input to the model
# Ops!! Something went wrong while inferring the model: {e}

# %% [markdown]
# I forgot to use f sring XD

# %%
# !git clone https://github.com/angeltamang123/URL-Content-Categorizer.git
# Out:
# Cloning into 'URL-Content-Categorizer'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 68 (delta 25), reused 53 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (68/68), 336.22 KiB | 10.19 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
# !python categorize.py --url https://www.trip.com/travel-guide
# Out:
# Requests scrape job starting....
# Requests scrape job completed with 69 words worth of content
# Playwright scrape job starting....
# Page loaded.
# Playwright working: 60/60s                    Playwright scrape job completed with 46 words worth of content
# Using the scraping output of requests with word count of 46
# as input to the model
# Ops!! Something went wrong while inferring the model: 401 Client Error. (Request ID: Root=1-68272803-2f0317e56da0f03a3c52dea1;ca584e7b-eb8c-43b2-b22a-e3857cdf3e9d)
#
# Repository Not Found for url: https://huggingface.co/api/spaces/Vyke2000/WebOrganizer-TopicClassifier-NoURL_on_Gradio_Spaces.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Invalid username or password.

# %% [markdown]
# *Now trying again with the gradio service available*

# %%
# !python categorize.py --url https://www.trip.com/travel-guide
# Out:
# Requests scrape job starting....
# Requests scrape job completed with 69 words worth of content
# Playwright scrape job starting....
# Page loaded.
# Playwright working: 60/60s                    Playwright scrape job completed with 46 words worth of content
# Using the scraping output of requests with word count of 46
# as input to the model
# Loaded as API: https://vyke2000-weborganizer-topicclassifier-nourl-on-g-4e2831b.hf.space ✔
# The topic is categorized as Travel with the model being 98.18% confident

# %% [markdown]
# Good enough, *now we use the script to just scraping purpose* using -s flag

# %%
# !python categorize.py -s --url https://www.vodafone.com/
# Out:
# Please choose your local Vodafone website
# Egypt (EN) RD Congo مصر Tanzania (EN) Ethiopia Kenya Moçambique Lesotho South Africa
# India Türkiye
# Shqipëri Nederland Česká Republika United Kingdom Deutschland Portugal España România Ελλάδα Ireland Italia
# ...

# %% [markdown]
# ## End
